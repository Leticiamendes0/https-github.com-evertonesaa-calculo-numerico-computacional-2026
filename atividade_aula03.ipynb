# %% [markdown]
# <a href="https://colab.research.google.com/github/Leticiamendes0/https-github.com-evertonesaa-calculo-numerico-computacional-2026/blob/main/atividade_aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x):
    return x**3 - x - 2


def bisseccao(f, a, b, n):
    for i in range(n):
        c = (a + b) / 2
        print("Iteração:", i, "C =", c)

        if f(a) * f(c) < 0:
            b = c
        else:
            a = c

    return (a + b) / 2
    # Chamando a função
raiz = bisseccao(f, 1, 2, 10)

print("A raiz aproximada é:", raiz)
# Out:
# Iteração: 0 C = 1.5
# Iteração: 1 C = 1.75
# Iteração: 2 C = 1.625
# Iteração: 3 C = 1.5625
# Iteração: 4 C = 1.53125
# Iteração: 5 C = 1.515625
# Iteração: 6 C = 1.5234375
# Iteração: 7 C = 1.51953125
# Iteração: 8 C = 1.521484375
# Iteração: 9 C = 1.5205078125
# A raiz aproximada é: 1.52099609375

# %% [markdown]
# ### O que aconteceu?
#         De início quando executamos o primeiro código até "return (a + b) / 2", não aparece nenhum resultado pois a função foi definida mas não executada, já com o termo "print", termo que mostra na tela a raiz aproximada da equação, ela foi executada.

# %%
def f(x):
    return x**3 - x - 2


def bisseccao(f, a, b, n):

    print("Iter |   a   |   b   |   c   |  f(c)")
    print("--------------------------------------")

    for i in range(n):

        c = (a + b) / 2

        print(i, "|", round(a,6), "|", round(b,6), "|", round(c,6), "|", round(f(c),6))

        if f(a) * f(c) < 0:
            b = c
        else:
            a = c

    return (a + b) / 2


raiz = bisseccao(f, 1, 2, 10)

print("\nRaiz aproximada:", raiz)
bisseccao(f,1,2,5)

bisseccao(f,1,2,10)

bisseccao(f,1,2,20)
# Out:
# Iter |   a   |   b   |   c   |  f(c)
# --------------------------------------
# 0 | 1 | 2 | 1.5 | -0.125
# 1 | 1.5 | 2 | 1.75 | 1.609375
# 2 | 1.5 | 1.75 | 1.625 | 0.666016
# 3 | 1.5 | 1.625 | 1.5625 | 0.252197
# 4 | 1.5 | 1.5625 | 1.53125 | 0.059113
# 5 | 1.5 | 1.53125 | 1.515625 | -0.034054
# 6 | 1.515625 | 1.53125 | 1.523438 | 0.01225
# 7 | 1.515625 | 1.523438 | 1.519531 | -0.010971
# 8 | 1.519531 | 1.523438 | 1.521484 | 0.000622
# 9 | 1.519531 | 1.521484 | 1.520508 | -0.005179
#
# Raiz aproximada: 1.52099609375
# Iter |   a   |   b   |   c   |  f(c)
# --------------------------------------
# 0 | 1 | 2 | 1.5 | -0.125
# 1 | 1.5 | 2 | 1.75 | 1.609375
# 2 | 1.5 | 1.75 | 1.625 | 0.666016
# 3 | 1.5 | 1.625 | 1.5625 | 0.252197
# 4 | 1.5 | 1.5625 | 1.53125 | 0.059113
# Iter |   a   |   b   |   c   |  f(c)
# --------------------------------------
# 0 | 1 | 2 | 1.5 | -0.125
# 1 | 1.5 | 2 | 1.75 | 1.609375
# 2 | 1.5 | 1.75 | 1.625 | 0.666016
# 3 | 1.5 | 1.625 | 1.5625 | 0.252197
# ...

# %% [markdown]
# ### O que acontece com o resultado?
#        Quando aumentamos o número de iterações no método da bisseção, o intervalo vai sendo dividido várias vezes e a aproximação da raiz fica cada vez mais precisa. Por isso o resultado com 20 iterações é mais próximo da raiz real do que com 5 ou 10.
