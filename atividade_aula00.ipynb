# %% [markdown]
# <a href="https://colab.research.google.com/github/Leticiamendes0/https-github.com-evertonesaa-calculo-numerico-computacional-2026/blob/main/atividade_aula00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math


math.sqrt(2)**2
# Out:
# 2.0000000000000004

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# ### questão 01-  Isso acontece porque o computador não trabalha com números exatos, e sim com aproximações.
# O número √2 tem infinitas casas decimais, então o computador guarda só um valor aproximado.
# Quando você eleva esse valor ao quadrado, esse pequeno erro aparece no resultado, fazendo com que não dê exatamente 2, mas algo muito próximo disso.
#
# ### questão 02- Não, isso não quer dizer que o computador não serve para a engenharia.
# O que acontece é que números como 0.1 e 0.2 também são guardados de forma aproximada pelo computador, e essa pequena diferença aparece na soma. Na engenharia, esses erros são esperados e controlados. Os projetos sempre trabalham com margens de erro e tolerâncias, então resultados assim não comprometem a segurança nem a confiabilidade. Por isso, mesmo com essas limitações, o computador continua sendo uma ferramenta indispensável na engenharia.
